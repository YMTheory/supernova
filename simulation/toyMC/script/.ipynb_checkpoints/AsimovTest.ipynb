# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-5nrm_l5x because the default path (/afs/ihep.ac.cn/users/m/miaoyu/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
def loadAsimovResults(filename, idx, num):
    arr = np.loadtxt(filename)
    res = [None for i in range(num)]
    for i in range(num):
        res[i] = arr[:, idx+i]
    return res

# %%
path = "/junofs/users/miaoyu/supernova/simulation/toyMC/results/"
prefix = "Garching82703_variedDist_"
suffix = "MOSensAsimov_CombSep.csv"

exp = "SuperK_"
cha = "eESIBD_"
dTNO_SK_totcomb, dchi2NO_SK_totcomb, dTNO_SK_part, dchi2NO_SK_part, dTNO_SK_sep, dchi2NO_SK_sep = loadAsimovResults(path+prefix+exp+"NO_"+cha+suffix, 1, 6)
dTIO_SK_totcomb, dchi2IO_SK_totcomb, dTIO_SK_part, dchi2IO_SK_part, dTIO_SK_sep, dchi2IO_SK_sep = loadAsimovResults(path+prefix+exp+"IO_"+cha+suffix, 1, 6)

exp = "HyperK_"
cha = "eESIBDshort_"
dTNO_HK_totcomb, dchi2NO_HK_totcomb, dTNO_HK_part, dchi2NO_HK_part, dTNO_HK_sep, dchi2NO_HK_sep = loadAsimovResults(path+prefix+exp+"NO_"+cha+suffix, 1, 6)
dTIO_HK_totcomb, dchi2IO_HK_totcomb, dTIO_HK_part, dchi2IO_HK_part, dTIO_HK_sep, dchi2IO_HK_sep = loadAsimovResults(path+prefix+exp+"IO_"+cha+suffix, 1, 6)

# %%
dist = np.arange(5, 11, 1)
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(dist, dchi2NO_SK_totcomb, "o-", color="blue", lw=2.5, label="SuperK: combined")
ax[0].plot(dist, dchi2NO_SK_part, "o:", color="blue", lw=2.5, label="SuperK: IBD tag eff.= 50%")
ax[0].plot(dist, dchi2NO_SK_sep, "o-.", color="blue", lw=2.5, label="SuperK: separately")
#ax[0].plot(dist, dchi2NO_HK_totcomb, "o-", color="darkorange", lw=2.5, label="HyperK: combined")
#ax[0].plot(dist, dchi2NO_HK_part, "o:", color="darkorange", lw=2.5, label="HyperK: IBD tag eff.= 50%")
#ax[0].plot(dist, dchi2NO_HK_sep, "o-.", color="darkorange", lw=2.5, label="HyperK: separately")
ax[0].set_xlabel("Distance [kpc]", fontsize=18)
ax[0].set_ylabel(r"$\Delta \chi^2$", fontsize=18)
ax[0].grid(True)
ax[0].legend(prop={"size":16})
ax[0].tick_params(axis="both", labelsize=15)
ax[0].set_title("NO", fontsize=18)
#ax[0].set_ylim(0, 20)

ax[1].plot(dist, dchi2IO_SK_totcomb, "o-", color="blue", lw=2.5, label="SuperK: combined")
ax[1].plot(dist, dchi2IO_SK_part, "o:", color="blue", lw=2.5, label="SuperK: IBD tag eff.= 50%")
ax[1].plot(dist, dchi2IO_SK_sep, "o-.", color="blue", lw=2.5, label="SuperK: separately")
#ax[1].plot(dist, dchi2IO_HK_totcomb, "o-", color="darkorange", lw=2.5, label="HyperK: combined")
#ax[1].plot(dist, dchi2IO_HK_part, "o:", color="darkorange", lw=2.5, label="HyperK: IBD tag eff.= 50%")
#ax[1].plot(dist, dchi2IO_HK_sep, "o-.", color="darkorange", lw=2.5, label="HyperK: separately")
ax[1].set_xlabel("Distance [kpc]", fontsize=18)
ax[1].set_ylabel(r"$\Delta \chi^2$", fontsize=18)
ax[1].grid(True)
ax[1].legend(prop={"size":16})
ax[1].tick_params(axis="both", labelsize=15)
ax[1].set_title("IO", fontsize=18)
#ax[1].set_ylim(0, 20)

plt.tight_layout()
plt.savefig("../../plots/Garching82703_variedDist_SuperK3cases_AsimovSens.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [28], in <cell line: 33>()
#      30 #ax[1].set_ylim(0, 20)
#      32 plt.tight_layout()
# ---> 33 plt.savefig("../plots/Garching82703_variedDist_SuperK3cases_AsimovSens.pdf")
#
# File /cvmfs/juno.ihep.ac.cn/sw/anaconda/Anaconda3-2020.11-Linux-x86_64/envs/root626/lib/python3.9/site-packages/matplotlib/pyplot.py:954, in savefig(*args, **kwargs)
#     951 @_copy_docstring_and_deprecators(Figure.savefig)
#     952 def savefig(*args, **kwargs):
#     953     fig = gcf()
# --> 954     res = fig.savefig(*args, **kwargs)
#     955     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     956     return res
#
# File /cvmfs/juno.ihep.ac.cn/sw/anaconda/Anaconda3-2020.11-Linux-x86_64/envs/root626/lib/python3.9/site-packages/matplotlib/figure.py:3274, in Figure.savefig(self, fname, transparent, **kwargs)
#    3270     for ax in self.axes:
#    3271         stack.enter_context(
#    3272             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3274 self.canvas.print_figure(fname, **kwargs)
#
# File /cvmfs/juno.ihep.ac.cn/sw/anaconda/Anaconda3-2020.11-Linux-x86_64/envs/root626/lib/python3.9/site-packages/matplotlib/backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File /cvmfs/juno.ihep.ac.cn/sw/anaconda/Anaconda3-2020.11-Linux-x86_64/envs/root626/lib/python3.9/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File /cvmfs/juno.ihep.ac.cn/sw/anaconda/Anaconda3-2020.11-Linux-x86_64/envs/root626/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py:2808, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2806     file = filename._file
#    2807 else:
# -> 2808     file = PdfFile(filename, metadata=metadata)
#    2809 try:
#    2810     file.newPage(width, height)
#
# File /cvmfs/juno.ihep.ac.cn/sw/anaconda/Anaconda3-2020.11-Linux-x86_64/envs/root626/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py:713, in PdfFile.__init__(self, filename, metadata)
#     711 self.original_file_like = None
#     712 self.tell_base = 0
# --> 713 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     714 if not opened:
#     715     try:
#
# File /cvmfs/juno.ihep.ac.cn/sw/anaconda/Anaconda3-2020.11-Linux-x86_64/envs/root626/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:492, in to_filehandle(fname, flag, return_opened, encoding)
#     490         fh = bz2.BZ2File(fname, flag)
#     491     else:
# --> 492         fh = open(fname, flag, encoding=encoding)
#     493     opened = True
#     494 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../plots/Garching82703_variedDist_SuperK3cases_AsimovSens.pdf'
